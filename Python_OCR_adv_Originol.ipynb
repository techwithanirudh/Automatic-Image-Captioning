# %% [markdown]
# <a href="https://colab.research.google.com/github/techwithanirudh/Automatic-Image-Captioning/blob/master/Python_OCR_adv_Originol.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://github.com/arthurflor23/handwritten-text-recognition/blob/master/doc/image/header.png?raw=true" />
#
# # Handwritten Text Recognition using TensorFlow 2.x
#
# This tutorial shows how you can use the project [Handwritten Text Recognition](https://github.com/arthurflor23/handwritten-text-recognition) in your Google Colab.

# %%
# %%javascript
# function ClickConnect() {
#   // console.log('Working')
#   // document
#   //   .querySelector('#top-toolbar > colab-connect-button')
#   //   .shadowRoot.querySelector('#connect')
#   //   .click()
#   aaaaaaaaaaa
# }
#
# setInterval(ClickConnect, 600)

# %%
# from google.colab import drive

# drive.mount("./gdrive", force_remount=True)
# import shutil

# shutil.rmtree('/content/gdrive/My Drive/handwritten-text-recognition')

# %mkdir "/content/gdrive/"
# %mkdir "/content/gdrive/My Drive/"
# %cd "/content/gdrive/My Drive/"
# !git clone https://github.com/arthurflor23/handwritten-text-recognition
# !mkdir "/content/gdrive/My Drive/handwritten-text-recognition/raw/bentham"
# !wget http://www.transcriptorium.eu/~tsdata/BenthamR0/BenthamDatasetR0-GT.zip
# !wget http://www.transcriptorium.eu/~tsdata/BenthamR0/BenthamDatasetR0-Images.zip
# !unzip "/content/gdrive/My Drive/BenthamDatasetR0-GT.zip" -d "/content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/"
# !unzip "/content/gdrive/My Drive/BenthamDatasetR0-Images.zip" -d "/content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/"

# import shutil

# shutil.rmtree('/content/gdrive/My Drive/handwritten-text-recognition')
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/073_071_004_01_02.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/071_140_001_01_01.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/071_183_004_04_04.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_108_003_01_14.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/096_008_004_01_06.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_112_003_02_20.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/072_048_003_04_13.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/072_049_004_04_04.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/071_130_003_02_01.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_008_001_02_05.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_111_003_02_01.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/096_051_002_03_18.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_084_002_02_07.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/116_294_001_02_01.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/071_184_001_04_06.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_075_004_02_25.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/116_279_002_01_01.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_008_001_02_04.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/116_639_002_02_02.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_072_003_02_22.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/116_072_001_02_26.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_107_002_01_02.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/096_053_004_03_15.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/116_627_001_03_17.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_078_002_02_08.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_016_003_01_06.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/071_165_003_05_01.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/071_182_001_05_07.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_086_004_02_07.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/116_291_001_04_14.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/116_068_001_02_31.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/071_181_003_02_01.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_077_002_02_24.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_077_001_02_23.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/096_028_001_01_04.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/096_021_003_02_02.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/116_392_001_04_07.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_073_002_02_17.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/071_054_001_03_02.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/071_185_001_04_05.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/071_184_001_04_01.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_016_001_01_10.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_087_004_02_17.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_010_002_02_12.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/096_051_004_03_05.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/071_131_004_05_03.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_080_004_02_18.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/071_018_002_05_08.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_009_001_03_16.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_072_003_02_06.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_082_004_02_30.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/116_627_002_03_16.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/073_067_001_03_18.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_010_002_02_01.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_065_003_02_11.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/072_169_002_04_13.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/073_071_003_03_07.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_111_004_02_02.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/096_052_002_03_19.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/096_053_004_03_24.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/115_075_003_02_14.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/071_044_003_04_20.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/072_210_004_04_17.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/071_192_004_04_09.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/071_054_002_02_01.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/071_185_002_04_10.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/116_387_001_01_22.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/071_002_002_04_03.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/116_616_001_03_17.txt
#  extracting: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/116_630_002_01_01.txt
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-GT/Transcriptions/071
jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_044_003.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/073_068_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_065_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/072_169_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_146_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/072_100_003.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/096_053_004.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_018_003.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/072_210_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/116_294_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/096_017_003.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_011_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_164_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/116_625_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_156_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/072_168_003.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/116_055_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_110_004.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/116_606_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/073_073_003.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/116_643_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/073_083_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_076_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/096_039_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/116_618_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/072_069_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/097_186_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_008_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_070_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_065_004.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/116_405_003.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_157_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_102_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_133_003.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/073_070_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_164_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_085_004.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_108_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/073_001_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/073_071_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_186_003.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_077_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/116_303_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/096_099_003.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/072_049_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/073_058_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/072_050_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_009_004.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_043_004.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/072_049_004.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_087_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_146_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/116_068_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/072_102_003.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/073_073_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/072_169_003.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_078_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_112_003.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_133_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/116_076_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_065_003.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/072_054_003.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_053_004.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/073_057_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_180_004.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/035_325_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_065_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/116_400_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_190_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_073_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_077_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_167_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_182_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_082_003.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_085_004.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/072_100_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_086_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_077_004.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/035_321_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/073_060_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_181_004.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_069_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_128_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/096_002_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_067_004.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_202_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/116_617_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/073_002_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/073_071_004.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/072_104_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/073_052_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/002_080_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_110_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/116_279_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_082_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_009_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_105_003.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/116_636_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/072_103_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/116_387_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/073_031_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/096_015_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_107_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_110_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_072_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/116_295_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/116_074_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/096_034_004.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/035_323_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/115_077_003.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_120_002.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_053_003.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/071_192_004.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/116_633_001.jpg
#   inflating: /content/gdrive/My Drive/handwritten-text-recognition/raw/bentham/BenthamDatasetR0-Images/Images/Pages/116_616_001.jpg

# %%
# parser.add_argument("--source", type=str, default='bentham')

# import os

# os.chdir('/content/gdrive/My Drive/handwritten-text-recognition')

    # raw_path = os.path.join("./", "raw", args.source)
    # source_path = os.path.join("./", "data", f"{args.source}.hdf5")
    # output_path = os.path.join("./", "output", args.source, args.arch)
    # target_path = os.path.join(output_path, "checkpoint_weights.hdf5")

# !apt-get install python3-venv
# !python -m venv .venv && source .venv/bin/activate
# !pip install -r "/content/gdrive/My Drive/handwritten-text-recognition/requirements.txt"
# !python "/content/gdrive/My Drive/handwritten-text-recognition/src/main.py" --transform
# Out:
# bentham dataset will be transformed...
# tcmalloc: large alloc 1154482176 bytes == 0x650c000 @  0x7effdc3e2001 0x7effd045c4ff 0x7effd04acb08 0x7effd04b0ac7 0x7effd054f1a3 0x50a4a5 0x50cc96 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x50ad03 0x634e72 0x634f27 0x6386df 0x639281 0x4b0dc0 0x7effdbfddbf7 0x5b259a
# 12288it [04:08, 49.40it/s]

# %% [markdown]
# ## 1 Localhost Environment
# <!--  -->
# We'll make sure you have the project in your Google Drive with the datasets in HDF5. If you already have structured files in the cloud, skip this step.

# %% [markdown]
# ### 1.1 Datasets
#
# The datasets that you can use:
#
# a. [Bentham](http://transcriptorium.eu/datasets/bentham-collection/)
#
# b. [IAM](http://www.fki.inf.unibe.ch/databases/iam-handwriting-database)
#
# c. [Rimes](http://www.a2ialab.com/doku.php?id=rimes_database:start)
#
# d. [Saint Gall](http://www.fki.inf.unibe.ch/databases/iam-historical-document-database/saint-gall-database)
#
# e. [Washington](http://www.fki.inf.unibe.ch/databases/iam-historical-document-database/washington-database)

# %% [markdown]
# ### 1.2 Raw folder
#
# On localhost, download the code project from GitHub and extract the chosen dataset (or all if you prefer) in the **raw** folder. Don't change anything of the structure of the dataset, since the scripts were made from the **original structure** of them. Your project directory will be like this:
#
# ```
# .
# ├── raw
# │   ├── bentham
# │   │   ├── BenthamDatasetR0-GT
# │   │   └── BenthamDatasetR0-Images
# │   ├── iam
# │   │   ├── ascii
# │   │   ├── forms
# │   │   ├── largeWriterIndependentTextLineRecognitionTask
# │   │   ├── lines
# │   │   └── xml
# │   ├── rimes
# │   │   ├── eval_2011
# │   │   ├── eval_2011_annotated.xml
# │   │   ├── training_2011
# │   │   └── training_2011.xml
# │   ├── saintgall
# │   │   ├── data
# │   │   ├── ground_truth
# │   │   ├── README.txt
# │   │   └── sets
# │   └── washington
# │       ├── data
# │       ├── ground_truth
# │       ├── README.txt
# │       └── sets
# └── src
#     ├── data
#     │   ├── evaluation.py
#     │   ├── generator.py
#     │   ├── preproc.py
#     │   ├── reader.py
#     │   ├── similar_error_analysis.py
#     ├── main.py
#     ├── network
#     │   ├── architecture.py
#     │   ├── layers.py
#     │   ├── model.py
#     └── tutorial.ipynb
#
# ```
#
# After that, create virtual environment and install the dependencies with python 3 and pip:
#
# > ```python -m venv .venv && source .venv/bin/activate```
#
# > ```pip install -r requirements.txt```

# %% [markdown]
# ### 1.3 HDF5 files
#
# Now, you'll run the *transform* function from **main.py**. For this, execute on **src** folder:
#
# > ```python main.py --source=<DATASET_NAME> --transform```
#
# Your data will be preprocess and encode, creating and saving in the **data** folder. Now your project directory will be like this:
#
#
# ```
# .
# ├── data
# │   ├── bentham.hdf5
# │   ├── iam.hdf5
# │   ├── rimes.hdf5
# │   ├── saintgall.hdf5
# │   └── washington.hdf5
# ├── raw
# │   ├── bentham
# │   │   ├── BenthamDatasetR0-GT
# │   │   └── BenthamDatasetR0-Images
# │   ├── iam
# │   │   ├── ascii
# │   │   ├── forms
# │   │   ├── largeWriterIndependentTextLineRecognitionTask
# │   │   ├── lines
# │   │   └── xml
# │   ├── rimes
# │   │   ├── eval_2011
# │   │   ├── eval_2011_annotated.xml
# │   │   ├── training_2011
# │   │   └── training_2011.xml
# │   ├── saintgall
# │   │   ├── data
# │   │   ├── ground_truth
# │   │   ├── README.txt
# │   │   └── sets
# │   └── washington
# │       ├── data
# │       ├── ground_truth
# │       ├── README.txt
# │       └── sets
# └── src
#     ├── data
#     │   ├── evaluation.py
#     │   ├── generator.py
#     │   ├── preproc.py
#     │   ├── reader.py
#     │   ├── similar_error_analysis.py
#     ├── main.py
#     ├── network
#     │   ├── architecture.py
#     │   ├── layers.py
#     │   ├── model.py
#     └── tutorial.ipynb
#
# ```
#
# Then upload the **data** and **src** folders in the same directory in your Google Drive.

# %% [markdown]
# ## 2 Google Drive Environment

# %% [markdown]
# ### 2.1 TensorFlow 2.x

# %% [markdown]
# Make sure the jupyter notebook is using GPU mode.

# %%
# !nvidia-smi
# Out:
# Fri Jan 29 03:04:13 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   65C    P0    31W /  70W |   4771MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# Now, we'll install and switch to TensorFlow 2.x.

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# ### 2.2 Google Drive

# %% [markdown]
# Mount your Google Drive partition.
#
# **Note:** *\"Colab Notebooks/handwritten-text-recognition/src/\"* was the directory where you put the project folders, specifically the **src** folder.

# %%
# from google.colab import drive

# drive.mount("./gdrive", force_remount=True)

# %cd '/content/'
# %cd "./gdrive/My Drive/handwritten-text-recognition/src/"
# !ls -l
# Out:
# /content
# /content/gdrive/My Drive/handwritten-text-recognition/src
# total 40
# drwxr-xr-x 3 root root  4096 Jan 29 02:57 data
# -rw-r--r-- 1 root root  9144 Jan 29 02:57 main.py
# drwxr-xr-x 3 root root  4096 Jan 29 02:57 network
# -rw-r--r-- 1 root root 16473 Jan 29 02:51 tutorial.ipynb

# %% [markdown]
# After mount, you can see the list os files in the project folder.

# %% [markdown]
# ## 3 Set Python Classes

# %% [markdown]
# ### 3.1 Environment

# %% [markdown]
# First, let's define our environment variables.
#
# Set the main configuration parameters, like input size, batch size, number of epochs and list of characters. This make compatible with **main.py** and jupyter notebook:
#
# * **dataset**: "bentham", "iam", "rimes", "saintgall", "washington"
#
# * **arch**: network to run: "bluche", "puigcerver", "flor"
#
# * **epochs**: number of epochs
#
# * **batch_size**: number size of the batch

# %%
import os
import datetime
import string


# define parameters
source = "bentham"
arch = "flor"
epochs = 100
batch_size = 16

# define paths
source_path = os.path.join("/content/gdrive/My Drive/handwritten-text-recognition/", "data", f"{source}.hdf5")
output_path = os.path.join("/content/gdrive/My Drive/handwritten-text-recognition/", "output", source, arch)
target_path = os.path.join(output_path, "checkpoint_weights.hdf5")
os.makedirs(output_path, exist_ok=True)

# define input size, number max of chars per line and list of valid chars
input_size = (1024, 128, 1)
max_text_length = 128
charset_base = string.printable[:95]

print("source:", source_path)
print("output", output_path)
print("target", target_path)
print("charset:", charset_base)
# Out:
# source: /content/gdrive/My Drive/handwritten-text-recognition/data/bentham.hdf5
# output /content/gdrive/My Drive/handwritten-text-recognition/output/bentham/flor
# target /content/gdrive/My Drive/handwritten-text-recognition/output/bentham/flor/checkpoint_weights.hdf5
# charset: 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %% [markdown]
# ### 3.2 DataGenerator Class

# %% [markdown]
# The second class is **DataGenerator()**, responsible for:
#
# * Load the dataset partitions (train, valid, test);
#
# * Manager batchs for train/validation/test process.

# %%
import os

os.chdir('/content/gdrive/My Drive/handwritten-text-recognition/src/')

from data.generator import DataGenerator

dtgen = DataGenerator(source=source_path,
                      batch_size=batch_size,
                      charset=charset_base,
                      max_text_length=max_text_length)

print(f"Train images: {dtgen.size['train']}")
print(f"Validation images: {dtgen.size['valid']}")
print(f"Test images: {dtgen.size['test']}")
# Out:
# Train images: 8808
# Validation images: 1372
# Test images: 820

# %% [markdown]
# ### 3.3 HTRModel Class

# %% [markdown]
# The third class is **HTRModel()**, was developed to be easy to use and to abstract the complicated flow of a HTR system. It's responsible for:
#
# * Create model with Handwritten Text Recognition flow, in which calculate the loss function by CTC and decode output to calculate the HTR metrics (CER, WER and SER);
#
# * Save and load model;
#
# * Load weights in the models (train/infer);
#
# * Make Train/Predict process using *generator*.
#
# To make a dynamic HTRModel, its parameters are the *architecture*, *input_size* and *vocab_size*.

# %%
from network.model import HTRModel

# create and compile HTRModel
model = HTRModel(architecture=arch,
                 input_size=input_size,
                 vocab_size=dtgen.tokenizer.vocab_size,
                 beam_width=10,
                 stop_tolerance=20,
                 reduce_tolerance=15)

model.compile(learning_rate=0.001)
model.summary(output_path, "summary.txt")

# get default callbacks and load checkpoint weights file (HDF5) if exists
model.load_checkpoint(target=target_path)

callbacks = model.get_callbacks(logdir=output_path, checkpoint=target_path, verbose=1)

# %% [markdown]
# ## 4 Training

# %% [markdown]
# The training process is similar to the *fit()* of the Keras. After training, the information (epochs and minimum loss) is save.

# %%
# to calculate total and average time per epoch
start_time = datetime.datetime.now()

h = model.fit(x=dtgen.next_train_batch(),
              epochs=epochs,
              steps_per_epoch=dtgen.steps['train'],
              validation_data=dtgen.next_valid_batch(),
              validation_steps=dtgen.steps['valid'],
              callbacks=callbacks,   
              shuffle=True,
              verbose=1)

total_time = datetime.datetime.now() - start_time

loss = h.history['loss']
val_loss = h.history['val_loss']

min_val_loss = min(val_loss)
min_val_loss_i = val_loss.index(min_val_loss)

time_epoch = (total_time / len(loss))
total_item = (dtgen.size['train'] + dtgen.size['valid'])

t_corpus = "\n".join([
    f"Total train images:      {dtgen.size['train']}",
    f"Total validation images: {dtgen.size['valid']}",
    f"Batch:                   {dtgen.batch_size}\n",
    f"Total time:              {total_time}",
    f"Time per epoch:          {time_epoch}",
    f"Time per item:           {time_epoch / total_item}\n",
    f"Total epochs:            {len(loss)}",
    f"Best epoch               {min_val_loss_i + 1}\n",
    f"Training loss:           {loss[min_val_loss_i]:.8f}",
    f"Validation loss:         {min_val_loss:.8f}"
])

with open(os.path.join(output_path, "train.txt"), "w") as lg:
    lg.write(t_corpus)
    print(t_corpus)
# Out:
# Epoch 1/100
# 551/551 [==============================] - ETA: 0s - loss: 151.2874
# Epoch 00001: val_loss improved from inf to 119.87994, saving model to /content/gdrive/My Drive/handwritten-text-recognition/output/bentham/flor/checkpoint_weights.hdf5
# 551/551 [==============================] - 218s 395ms/step - loss: 151.2874 - val_loss: 119.8799
# Epoch 2/100
# 551/551 [==============================] - ETA: 0s - loss: 93.4474
# Epoch 00002: val_loss improved from 119.87994 to 69.18131, saving model to /content/gdrive/My Drive/handwritten-text-recognition/output/bentham/flor/checkpoint_weights.hdf5
# 551/551 [==============================] - 215s 390ms/step - loss: 93.4474 - val_loss: 69.1813
# Epoch 3/100
# 551/551 [==============================] - ETA: 0s - loss: 52.7680
# Epoch 00003: val_loss improved from 69.18131 to 46.74471, saving model to /content/gdrive/My Drive/handwritten-text-recognition/output/bentham/flor/checkpoint_weights.hdf5
# Epoch 00085: val_loss did not improve from 10.03346
# 551/551 [==============================] - 215s 390ms/step - loss: 7.5134 - val_loss: 10.2607
# Epoch 86/100
# 551/551 [==============================] - ETA: 0s - loss: 7.6027
# Epoch 00086: val_loss did not improve from 10.03346
# 551/551 [==============================] - 215s 390ms/step - loss: 7.6027 - val_loss: 10.0518
# Epoch 87/100
# 551/551 [==============================] - ETA: 0s - loss: 7.5028
# Epoch 00087: val_loss did not improve from 10.03346
# 551/551 [==============================] - 214s 388ms/step - loss: 7.5028 - val_loss: 10.0536
# Epoch 88/100
# 551/551 [==============================] - ETA: 0s - loss: 7.5259
# Epoch 00088: val_loss did not improve from 10.03346
#
# Epoch 00088: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 551/551 [==============================] - 214s 388ms/step - loss: 7.5259 - val_loss: 10.3625
# Epoch 89/100
# 551/551 [==============================] - ETA: 0s - loss: 6.4790
# Epoch 00089: val_loss improved from 10.03346 to 9.53777, saving model to /content/gdrive/My Drive/handwritten-text-recognition/output/bentham/flor/checkpoint_weights.hdf5
# 551/551 [==============================] - 214s 389ms/step - loss: 6.4790 - val_loss: 9.5378
# Epoch 90/100
# 551/551 [==============================] - ETA: 0s - loss: 6.1324
# Epoch 00090: val_loss improved from 9.53777 to 9.26426, saving model to /content/gdrive/My Drive/handwritten-text-recognition/output/bentham/flor/checkpoint_weights.hdf5
# 551/551 [==============================] - 215s 389ms/step - loss: 6.1324 - val_loss: 9.2643
# Epoch 91/100
# 551/551 [==============================] - ETA: 0s - loss: 6.0254
# Epoch 00091: val_loss improved from 9.26426 to 9.24872, saving model to /content/gdrive/My Drive/handwritten-text-recognition/output/bentham/flor/checkpoint_weights.hdf5
# 551/551 [==============================] - 214s 388ms/step - loss: 6.0254 - val_loss: 9.2487
# Epoch 92/100
# 551/551 [==============================] - ETA: 0s - loss: 5.8767
# Epoch 00092: val_loss did not improve from 9.24872
# 551/551 [==============================] - 214s 388ms/step - loss: 5.8767 - val_loss: 9.3143
# Epoch 93/100
# 551/551 [==============================] - ETA: 0s - loss: 5.6639
# Epoch 00093: val_loss improved from 9.24872 to 9.11002, saving model to /content/gdrive/My Drive/handwritten-text-recognition/output/bentham/flor/checkpoint_weights.hdf5
# 551/551 [==============================] - 215s 390ms/step - loss: 5.6639 - val_loss: 9.1100
# Epoch 94/100
# 551/551 [==============================] - ETA: 0s - loss: 5.6403
# Epoch 00094: val_loss did not improve from 9.11002
# 551/551 [==============================] - 214s 389ms/step - loss: 5.6403 - val_loss: 9.1641
# Epoch 95/100
# 551/551 [==============================] - ETA: 0s - loss: 5.5854
# Epoch 00095: val_loss did not improve from 9.11002
# 551/551 [==============================] - 215s 390ms/step - loss: 5.5854 - val_loss: 9.1750
# Epoch 96/100
# 551/551 [==============================] - ETA: 0s - loss: 5.6458
# Epoch 00096: val_loss did not improve from 9.11002
# 551/551 [==============================] - 215s 389ms/step - loss: 5.6458 - val_loss: 9.1207
# Epoch 97/100
# 551/551 [==============================] - ETA: 0s - loss: 5.5109
# Epoch 00097: val_loss did not improve from 9.11002
# 551/551 [==============================] - 215s 390ms/step - loss: 5.5109 - val_loss: 9.1207
# Epoch 98/100
# 551/551 [==============================] - ETA: 0s - loss: 5.2453
# Epoch 00098: val_loss improved from 9.11002 to 9.09830, saving model to /content/gdrive/My Drive/handwritten-text-recognition/output/bentham/flor/checkpoint_weights.hdf5
# 551/551 [==============================] - 215s 390ms/step - loss: 5.2453 - val_loss: 9.0983
# Epoch 99/100
# 551/551 [==============================] - ETA: 0s - loss: 5.4110
# Epoch 00099: val_loss improved from 9.09830 to 9.06706, saving model to /content/gdrive/My Drive/handwritten-text-recognition/output/bentham/flor/checkpoint_weights.hdf5
# 551/551 [==============================] - 215s 390ms/step - loss: 5.4110 - val_loss: 9.0671
# Epoch 100/100
# 551/551 [==============================] - ETA: 0s - loss: 5.1739
# Epoch 00100: val_loss improved from 9.06706 to 8.97449, saving model to /content/gdrive/My Drive/handwritten-text-recognition/output/bentham/flor/checkpoint_weights.hdf5
# 551/551 [==============================] - 215s 390ms/step - loss: 5.1739 - val_loss: 8.9745
# Total train images:      8808
# Total validation images: 1372
# Batch:                   16
#
# Total time:              5:58:06.382639
# Time per epoch:          0:03:34.863826
# Time per item:           0:00:00.021106
#
# Total epochs:            100
# Best epoch               100
#
# Training loss:           5.17386532
# Validation loss:         8.97449207

# %% [markdown]
# ## 5 Predict

# %% [markdown]
# The predict process is similar to the *predict* of the Keras:

# %%
from data import preproc as pp
from google.colab.patches import cv2_imshow

start_time = datetime.datetime.now()

# predict() function will return the predicts with the probabilities
predicts, _ = model.predict(x=dtgen.next_test_batch(),
                            steps=dtgen.steps['test'],
                            ctc_decode=True,
                            verbose=1)

# decode to string
predicts = [dtgen.tokenizer.decode(x[0]) for x in predicts]
ground_truth = [x.decode() for x in dtgen.dataset['test']['gt']]

total_time = datetime.datetime.now() - start_time

# mount predict corpus file
with open(os.path.join(output_path, "predict.txt"), "w") as lg:
    for pd, gt in zip(predicts, ground_truth):
        lg.write(f"TE_L {gt}\nTE_P {pd}\n")
   
for i, item in enumerate(dtgen.dataset['test']['dt'][:10]):
    print("=" * 1024, "\n")
    cv2_imshow(pp.adjust_to_see(item))
    print(ground_truth[i])
    print(predicts[i], "\n")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-a711f67fcea0> in <module>()
#       8                             steps=dtgen.steps['test'],
#       9                             ctc_decode=True,
# ---> 10                             verbose=1)
#      11
#      12 # decode to string
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     128       raise ValueError('{} is not supported in multi-worker mode.'.format(
#     129           method.__name__))
# --> 130     return method(self, *args, **kwargs)
#     131
#     132   return tf_decorator.make_decorator(
#
# TypeError: predict() got an unexpected keyword argument 'ctc_decode'

# %%
from data import preproc as pp
from google.colab.patches import cv2_imshow
from keras import models
import os
from google.colab import files

os.chdir('/content/gdrive/My Drive/handwritten-text-recognition/src/')

_files = files.upload()

for file in _files:
  file = file
file = '/content/model/'
print(file)


model = models.load_model(file)

start_time = datetime.datetime.now()

# predict() function will return the predicts with the probabilities
predicts, _ = model.predict(x=dtgen.next_test_batch(),
                            steps=dtgen.steps['test'],
                            ctc_decode=True,
                            verbose=1)

# decode to string
predicts = [dtgen.tokenizer.decode(x[0]) for x in predicts]
ground_truth = [x.decode() for x in dtgen.dataset['test']['gt']]

total_time = datetime.datetime.now() - start_time

# mount predict corpus file
with open(os.path.join(output_path, "predict.txt"), "w") as lg:
    for pd, gt in zip(predicts, ground_truth):
        lg.write(f"TE_L {gt}\nTE_P {pd}\n")
   
for i, item in enumerate(dtgen.dataset['test']['dt'][:10]):
    print("=" * 1024, "\n")
    cv2_imshow(pp.adjust_to_see(item))
    print(ground_truth[i])
    print(predicts[i], "\n")
# Out:
#      <input type="file" id="files-b2a2897d-efba-4f2e-8d91-9c668ff8bc10" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b2a2897d-efba-4f2e-8d91-9c668ff8bc10">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# /content/model/
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-8131631f84a9> in <module>()
#      15
#      16
# ---> 17 model = models.load_model(file)
#      18
#      19 start_time = datetime.datetime.now()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     185     if isinstance(filepath, six.string_types):
#     186       loader_impl.parse_saved_model(filepath)
# --> 187       return saved_model_load.load(filepath, compile, options)
#     188
#     189   raise IOError(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/saved_model/load.py in load(path, compile, options)
#     129     if training_config is not None:
#     130       model.compile(**saving_utils.compile_args_from_training_config(
# --> 131           training_config))
#     132       saving_utils.try_build_compiled_arguments(model)
#     133     else:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/saving_utils.py in compile_args_from_training_config(training_config, custom_objects)
#     215     loss_config = training_config.get('loss', None)
#     216     if loss_config is not None:
# --> 217       loss = _deserialize_nested_config(losses.deserialize, loss_config)
#     218
#     219     # Recover metrics.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/saving_utils.py in _deserialize_nested_config(deserialize_fn, config)
#     256     return None
#     257   if _is_single_object(config):
# --> 258     return deserialize_fn(config)
#     259   elif isinstance(config, dict):
#     260     return {
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/losses.py in deserialize(name, custom_objects)
#    1852       module_objects=globals(),
#    1853       custom_objects=custom_objects,
# -> 1854       printable_module_name='loss function')
#    1855
#    1856
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     376       if obj is None:
#     377         raise ValueError(
# --> 378             'Unknown ' + printable_module_name + ': ' + object_name)
#     379     # Classes passed by name are instantiated with no args, functions are
#     380     # returned as-is.
#
# ValueError: Unknown loss function: ctc_loss_lambda_func

# %%
model.model.save('/content/model')
# !zip -r /content/model.zip /content/model

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# !cp /content/model -r /content/drive/MyDrive/model-hand-written-text-recognition

# %% [markdown]
# ## 6 Evaluate

# %% [markdown]
# Evaluation process is more manual process. Here we have the `ocr_metrics`, but feel free to implement other metrics instead. In the function, we have three parameters:
#
# * predicts
# * ground_truth
# * norm_accentuation (calculation with/without accentuation)
# * norm_punctuation (calculation with/without punctuation marks)

# %%
from data import evaluation

evaluate = evaluation.ocr_metrics(predicts, ground_truth)

e_corpus = "\n".join([
    f"Total test images:    {dtgen.size['test']}",
    f"Total time:           {total_time}",
    f"Time per item:        {total_time / dtgen.size['test']}\n",
    f"Metrics:",
    f"Character Error Rate: {evaluate[0]:.8f}",
    f"Word Error Rate:      {evaluate[1]:.8f}",
    f"Sequence Error Rate:  {evaluate[2]:.8f}"
])

with open(os.path.join(output_path, "evaluate.txt"), "w") as lg:
    lg.write(e_corpus)
    print(e_corpus)
# Out:
# Total test images:    820
# Total time:           0:01:36.881203
# Time per item:        0:00:00.118148
#
# Metrics:
# Character Error Rate: 0.08656930
# Word Error Rate:      0.34298517
# Sequence Error Rate:  0.81341463
